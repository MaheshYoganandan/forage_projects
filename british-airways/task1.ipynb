# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10
page_size = 100

reviews = []

for i in range(1, pages + 1):
    print(f"Scraping page {i}")
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"
    response = requests.get(url)
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text().strip())  # Added strip() to remove extra whitespace
    print(f"   ---> {len(reviews)} total reviews")

# To write reviews to a file
with open("british_airways_reviews.txt", "w", encoding="utf-8") as f:
    for review in reviews:
        f.write(review + "\n")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified | Absolutely atrocious. LHR-OR...
# 1  ✅ Trip Verified | As someone who flies relentl...
# 2  ✅ Trip Verified |   Flew with British Airways ...
# 3  ✅ Trip Verified |   Straightforward check in T...
# 4  Not Verified | I am beyond upset and disgusted...

# %%
df
# Out:
#                                                reviews
# 0    ✅ Trip Verified | Absolutely atrocious. LHR-OR...
# 1    ✅ Trip Verified | As someone who flies relentl...
# 2    ✅ Trip Verified |   Flew with British Airways ...
# 3    ✅ Trip Verified |   Straightforward check in T...
# 4    Not Verified | I am beyond upset and disgusted...
# ..                                                 ...
# 995  ✅ Trip Verified |  I would like to praise the ...
# 996  ✅ Trip Verified | Madrid to London Heathrow. T...
# 997  ✅ Trip Verified | BA762 Heathrow to Oslo I hav...
# 998  ✅ Trip Verified | Hamburg to Abu Dhabi via Lon...
# 999  ✅ Trip Verified | New York to Glasgow via Lond...
#
# [1000 rows x 1 columns]

# %% [markdown]
# Removing the parts before | in the reviews column

# %%
df.reviews= df.reviews.str.split('|',expand=True)[1]

# %%
df
# Out:
#                                                reviews
# 0     Absolutely atrocious. LHR-ORD-LHR Round-trip....
# 1     As someone who flies relentlessly with Britis...
# 2       Flew with British Airways club Europe on Sa...
# 3       Straightforward check in T5. New site for c...
# 4     I am beyond upset and disgusted with the disr...
# ..                                                 ...
# 995    I would like to praise the outstanding court...
# 996   Madrid to London Heathrow. This was my second...
# 997   BA762 Heathrow to Oslo I have flown with BA a...
# 998   Hamburg to Abu Dhabi via London Heathrow. Ini...
# 999   New York to Glasgow via London. A routine and...
#
# [1000 rows x 1 columns]

# %% [markdown]
# **Rule-based Approach**
# This is a practical approach to analyzing text without training or using machine learning models. The result of this approach is a set of rules based on which the text is labeled as positive/negative/neutral. These rules are also known as lexicons. Hence, the Rule-based approach is called Lexicon based approach.
#
# **Widely used Lexicon-based Approaches**
# * TextBlob
# * VADER
# * SentiWordNet
#
# **Data Preprocessing Steps**
# 1. **Cleaning the text**
# 2. **Tokenization**
# 3. **Enrichment** - POS tagging
# 4. **Stopwords removal**
# 5. **Obtaining stem words**

# %% [markdown]
# ### Step 1: Cleaning the text

# %%
import re

# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text

# Cleaning the text in the review column
df['Cleaned Reviews'] = df['reviews'].apply(clean)
df.head()
# Out:
#                                                                                                reviews                                                                                      Cleaned Reviews                                                                                           POS tagged                                                                                                Lemma  Sentiment  Analysis
# 0   Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...   Absolutely atrocious LHR ORD LHR Round trip British Airways is truly a disgrace as our national...  [(Absolutely, r), (atrocious, a), (LHR, n), (ORD, n), (LHR, n), (Round, n), (trip, n), (British,...    Absolutely atrocious LHR ORD LHR Round trip British Airways truly disgrace national airline ei...    -0.9589  Negative
# 1   As someone who flies relentlessly with British Airways for business and pleasure, generally for...   As someone who flies relentlessly with British Airways for business and pleasure generally for ...  [(someone, n), (flies, v), (relentlessly, r), (British, n), (Airways, n), (business, n), (pleasu...    someone fly relentlessly British Airways business pleasure generally routing Gold frequent fli...     0.8271  Positive
# 2     Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...   Flew with British Airways club Europe on Saturday st August Poor lounge in Berlin Brandenburg a...  [(Flew, n), (British, n), (Airways, n), (club, v), (Europe, n), (Saturday, n), (st, v), (August,...    Flew British Airways club Europe Saturday st August Poor lounge Berlin Brandenburg airport Ema...    -0.8402  Negative
# 3     Straightforward check in T5. New site for club check in and it works well. All lounges busy b...   Straightforward check in T New site for club check in and it works well All lounges busy but go...  [(Straightforward, n), (check, n), (New, n), (site, n), (club, n), (check, n), (works, v), (well...    Straightforward check New site club check work well lounge busy good food offering time depart...     0.8176  Positive
# 4   I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...   I am beyond upset and disgusted with the disregard lack of knowledge and lies that your company...  [(beyond, None), (upset, n), (disgusted, v), (disregard, a), (lack, n), (knowledge, n), (lies, v...    beyond upset disgust disregard lack knowledge lie company put call different representative le...    -0.9462  Negative

# %%
# Out:
#                                                                                                  reviews                                                                                      Cleaned Reviews
# 0     Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...   Absolutely atrocious LHR ORD LHR Round trip British Airways is truly a disgrace as our national...
# 1     As someone who flies relentlessly with British Airways for business and pleasure, generally for...   As someone who flies relentlessly with British Airways for business and pleasure generally for ...
# 2       Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...   Flew with British Airways club Europe on Saturday st August Poor lounge in Berlin Brandenburg a...
# 3       Straightforward check in T5. New site for club check in and it works well. All lounges busy b...   Straightforward check in T New site for club check in and it works well All lounges busy but go...
# 4     I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...   I am beyond upset and disgusted with the disregard lack of knowledge and lies that your company...
# ..                                                                                                   ...                                                                                                  ...
# 995    I would like to praise the outstanding courtesy and service I received from the BA cabin crew ...   I would like to praise the outstanding courtesy and service I received from the BA cabin crew m...
# 996   Madrid to London Heathrow. This was my second trip Madrid to London on British Airways since Ma...   Madrid to London Heathrow This was my second trip Madrid to London on British Airways since May...
# 997   BA762 Heathrow to Oslo I have flown with BA a few times in the last few months, I have came off...   BA Heathrow to Oslo I have flown with BA a few times in the last few months I have came off med...
# 998   Hamburg to Abu Dhabi via London Heathrow. Initial flight from Heathrow to Abu Dhabi was cancell...   Hamburg to Abu Dhabi via London Heathrow Initial flight from Heathrow to Abu Dhabi was cancelle...
# 999   New York to Glasgow via London. A routine and smooth overnight flight that departed the gate ab...   New York to Glasgow via London A routine and smooth overnight flight that departed the gate abo...
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Step 2: Tokenization
# Tokenization is the process of breaking the text into smaller pieces called Tokens. It can be performed at sentences(sentence tokenization) or word level(word tokenization).
#
# ### Step 3: Enrichment – POS tagging
# Parts of Speech (POS) tagging is a process of converting each token into a tuple having the form (word, tag). POS tagging essential to preserve the context of the word and is essential for Lemmatization.
#
# ### Step 4: Stopwords removal
# Stopwords in English are words that carry very little useful information. We need to remove them as part of text preprocessing. nltk has a list of stopwords of every language.
#
# ### Step 5: Obtaining the stem words
# A stem is a part of a word responsible for its lexical meaning. The two popular techniques of obtaining the root/stem words are Stemming and Lemmatization.
#
# The key difference is Stemming often gives some meaningless root words as it simply chops off some characters in the end. Lemmatization gives meaningful root words, however, it requires POS tags of the words.
#
# NLTK is a leading platform for building Python programs to work with human language data.
#
# It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along
# with a suite of text processing libraries for classification, tokenization, stemming, tagging,
# parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries

# %%
import nltk

"""This punkt tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, 
collocations, and words that start sentences. """

nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mahes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mahes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mahes\AppData\Roaming\nltk_data...

# %%
#The nltk.corpus package defines a collection of corpus reader classes, which can be used to access the contents of a diverse set of corpora.


nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    #print(tags)
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
          newlist.append(tuple([word, pos_dict.get(tag[0])]))
          #print(tag[0])
          #print(pos_dict.get(tag[0]))
    return newlist 

df['POS tagged'] = df['Cleaned Reviews'].apply(token_stop_pos)
df.head()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mahes\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mahes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
#                                                                                                reviews                                                                                      Cleaned Reviews                                                                                           POS tagged
# 0   Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...   Absolutely atrocious LHR ORD LHR Round trip British Airways is truly a disgrace as our national...  [(Absolutely, r), (atrocious, a), (LHR, n), (ORD, n), (LHR, n), (Round, n), (trip, n), (British,...
# 1   As someone who flies relentlessly with British Airways for business and pleasure, generally for...   As someone who flies relentlessly with British Airways for business and pleasure generally for ...  [(someone, n), (flies, v), (relentlessly, r), (British, n), (Airways, n), (business, n), (pleasu...
# 2     Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...   Flew with British Airways club Europe on Saturday st August Poor lounge in Berlin Brandenburg a...  [(Flew, n), (British, n), (Airways, n), (club, v), (Europe, n), (Saturday, n), (st, v), (August,...
# 3     Straightforward check in T5. New site for club check in and it works well. All lounges busy b...   Straightforward check in T New site for club check in and it works well All lounges busy but go...  [(Straightforward, n), (check, n), (New, n), (site, n), (club, n), (check, n), (works, v), (well...
# 4   I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...   I am beyond upset and disgusted with the disregard lack of knowledge and lies that your company...  [(beyond, None), (upset, n), (disgusted, v), (disregard, a), (lack, n), (knowledge, n), (lies, v...

# %%
# Obtaining the stem words – Lemmatization

from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
     if not pos:
        lemma = word
        lemma_rew = lemma_rew + " " + lemma
     else:
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

df['Lemma'] = df['POS tagged'].apply(lemmatize)
df.head()
# Out:
#                                                                                                reviews                                                                                      Cleaned Reviews                                                                                           POS tagged                                                                                                Lemma
# 0   Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...   Absolutely atrocious LHR ORD LHR Round trip British Airways is truly a disgrace as our national...  [(Absolutely, r), (atrocious, a), (LHR, n), (ORD, n), (LHR, n), (Round, n), (trip, n), (British,...    Absolutely atrocious LHR ORD LHR Round trip British Airways truly disgrace national airline ei...
# 1   As someone who flies relentlessly with British Airways for business and pleasure, generally for...   As someone who flies relentlessly with British Airways for business and pleasure generally for ...  [(someone, n), (flies, v), (relentlessly, r), (British, n), (Airways, n), (business, n), (pleasu...    someone fly relentlessly British Airways business pleasure generally routing Gold frequent fli...
# 2     Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...   Flew with British Airways club Europe on Saturday st August Poor lounge in Berlin Brandenburg a...  [(Flew, n), (British, n), (Airways, n), (club, v), (Europe, n), (Saturday, n), (st, v), (August,...    Flew British Airways club Europe Saturday st August Poor lounge Berlin Brandenburg airport Ema...
# 3     Straightforward check in T5. New site for club check in and it works well. All lounges busy b...   Straightforward check in T New site for club check in and it works well All lounges busy but go...  [(Straightforward, n), (check, n), (New, n), (site, n), (club, n), (check, n), (works, v), (well...    Straightforward check New site club check work well lounge busy good food offering time depart...
# 4   I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...   I am beyond upset and disgusted with the disregard lack of knowledge and lies that your company...  [(beyond, None), (upset, n), (disgusted, v), (disregard, a), (lack, n), (knowledge, n), (lies, v...    beyond upset disgust disregard lack knowledge lie company put call different representative le...

# %%
df[['reviews','Lemma']]
# Out:
#                                                                                                  reviews                                                                                                Lemma
# 0     Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...    Absolutely atrocious LHR ORD LHR Round trip British Airways truly disgrace national airline ei...
# 1     As someone who flies relentlessly with British Airways for business and pleasure, generally for...    someone fly relentlessly British Airways business pleasure generally routing Gold frequent fli...
# 2       Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...    Flew British Airways club Europe Saturday st August Poor lounge Berlin Brandenburg airport Ema...
# 3       Straightforward check in T5. New site for club check in and it works well. All lounges busy b...    Straightforward check New site club check work well lounge busy good food offering time depart...
# 4     I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...    beyond upset disgust disregard lack knowledge lie company put call different representative le...
# ..                                                                                                   ...                                                                                                  ...
# 995    I would like to praise the outstanding courtesy and service I received from the BA cabin crew ...    would like praise outstanding courtesy service receive BA cabin crew member flight BA London H...
# 996   Madrid to London Heathrow. This was my second trip Madrid to London on British Airways since Ma...    Madrid London Heathrow second trip Madrid London British Airways since May trip like previous ...
# 997   BA762 Heathrow to Oslo I have flown with BA a few times in the last few months, I have came off...    BA Heathrow Oslo fly BA time last month come medication make nervous fly plane notify cabin cr...
# 998   Hamburg to Abu Dhabi via London Heathrow. Initial flight from Heathrow to Abu Dhabi was cancell...    Hamburg Abu Dhabi via London Heathrow Initial flight Heathrow Abu Dhabi cancel fly day earlier...
# 999   New York to Glasgow via London. A routine and smooth overnight flight that departed the gate ab...    New York Glasgow via London routine smooth overnight flight depart gate minute late security i...
#
# [1000 rows x 2 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


# function to calculate vader sentiment
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

df['Sentiment'] = df['Lemma'].apply(vadersentimentanalysis)

# function to analyse
def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'
df['Analysis'] = df['Sentiment'].apply(vader_analysis)
df.head()
# Out:
#                                                                                                reviews                                                                                      Cleaned Reviews                                                                                           POS tagged                                                                                                Lemma  Sentiment  Analysis
# 0   Absolutely atrocious. LHR-ORD-LHR Round-trip. British Airways is truly a disgrace as our "natio...   Absolutely atrocious LHR ORD LHR Round trip British Airways is truly a disgrace as our national...  [(Absolutely, r), (atrocious, a), (LHR, n), (ORD, n), (LHR, n), (Round, n), (trip, n), (British,...    Absolutely atrocious LHR ORD LHR Round trip British Airways truly disgrace national airline ei...    -0.9589  Negative
# 1   As someone who flies relentlessly with British Airways for business and pleasure, generally for...   As someone who flies relentlessly with British Airways for business and pleasure generally for ...  [(someone, n), (flies, v), (relentlessly, r), (British, n), (Airways, n), (business, n), (pleasu...    someone fly relentlessly British Airways business pleasure generally routing Gold frequent fli...     0.8271  Positive
# 2     Flew with British Airways club Europe on Saturday 31st August. Poor lounge in Berlin Brandenb...   Flew with British Airways club Europe on Saturday st August Poor lounge in Berlin Brandenburg a...  [(Flew, n), (British, n), (Airways, n), (club, v), (Europe, n), (Saturday, n), (st, v), (August,...    Flew British Airways club Europe Saturday st August Poor lounge Berlin Brandenburg airport Ema...    -0.8402  Negative
# 3     Straightforward check in T5. New site for club check in and it works well. All lounges busy b...   Straightforward check in T New site for club check in and it works well All lounges busy but go...  [(Straightforward, n), (check, n), (New, n), (site, n), (club, n), (check, n), (works, v), (well...    Straightforward check New site club check work well lounge busy good food offering time depart...     0.8176  Positive
# 4   I am beyond upset and disgusted with the disregard, lack of knowledge and lies that your compan...   I am beyond upset and disgusted with the disregard lack of knowledge and lies that your company...  [(beyond, None), (upset, n), (disgusted, v), (disregard, a), (lack, n), (knowledge, n), (lies, v...    beyond upset disgust disregard lack knowledge lie company put call different representative le...    -0.9462  Negative

# %%
vader_counts = df['Analysis'].value_counts()
vader_counts
# Out:
# Analysis
# Positive    464
# Negative    425
# Neutral     111
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,7))

plt.subplot(1,3,2)
plt.title("Reviews Analysis")
plt.pie(vader_counts.values, labels = vader_counts.index, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b864362a50>,
#   <matplotlib.patches.Wedge at 0x2b8643708d0>,
#   <matplotlib.patches.Wedge at 0x2b864372810>],
#  [Text(0.12414206920532637, 1.0929724363648976, 'Positive'),
#   Text(-0.4901302603462026, -0.984770190396198, 'Negative'),
#   Text(1.2687461318934807, -0.4612843513553554, 'Neutral')],
#  [Text(0.06771385593017801, 0.5961667834717622, '46.4%'),
#   Text(-0.2673437783706559, -0.5371473765797443, '42.5%'),
#   Text(0.7988401571181173, -0.29043829529781634, '11.1%')])

# %%
df.to_csv("BA_reviews.csv")

# %%
# Import the required libraries
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Your code remains the same
stopwords = set(STOPWORDS)

def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=100,
        max_font_size=30,
        scale=3,
        random_state=1)

    wordcloud = wordcloud.generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(df.Lemma)
